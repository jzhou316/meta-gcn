# %%
import matplotlib.pyplot as plt

# %%
# nlayers = [2, 4, 6, 8, 10, 12]
nlayers = [1, 2, 3, 4, 6, 8, 10, 12]

# %%
# debru_10k_rh1_f1 = [99.19, 99.87, 99.913, 99.907, 99.918, 99.924]   # no bias
debru_10k_rh1_f1 = [97.938, 99.328, 99.756, 99.867, 99.911, 99.918, 99.907, 99.921]
debru_10k_rh0_f1 = [97.939, 99.358, 99.884, 99.869, 99.921, 99.934, 99.928, 99.924]

# %%
# kadem_10k_rh1_f1 = [93.918, 98.48, 99.076, 99.254, 99.156, 99.143]  # no bias
kadem_10k_rh1_f1 = [58.643, 94.439, 97.807, 98.458, 99.087, 99.244, 99.376, 99.126]
kadem_10k_rh0_f1 = [60.236, 93.092, 97.218, 97.414, 98.505, 98.677, 98.667, 98.788]

# %%
# chord_10k_rh1_f1 = [89.901, 97.825, 99.004, 99.048, 99.165, 99.023]  # no bias
# chord_10k_rh1_f1 = [56.392, 90.965, 97.379, 97.658, 99.039, 99.075, 99.006, 99.216]
chord_10k_rh1_f1 = [56.392, 90.965, 97.256, 97.658, 99.039, 99.075, 99.006, 99.216]
chord_10k_rh0_f1 = [56.669, 89.032, 97.522, 97.531, 97.961, 98.618, 98.6, 98.084]

# %%
# leet_10k_rh1_f1 = [96.942, 98.97, 99.358, 99.363, 99.161, 99.475]  # no bias
leet_10k_rh1_f1 = [77.289, 97.116, 98.814, 99.063, 99.166, 99.341, 99.333, 99.457]
leet_10k_rh0_f1 = [77.305, 96.496, 98.842, 99.025, 98.86, 98.774, 99.31, 98.83]

# %%
c2_3k_rh1_f1 = [0, 0, 85.87, 98.925, 99.274, 99.307, 98.904, 99.374]
c2_3k_rh0_f1 = [0, 0, 93.62, 98.9, 98.997, 99.2, 99.224, 98.988]

# %%
p2p_3k_rh1_f1 = [0, 0.154, 98.448, 99.488, 99.154, 99.4, 99.7, 99.582]
p2p_3k_rh0_f1 = [0, 0.022, 99.342, 99.556, 99.57, 99.785, 99.578, 99.581]

# %%
plt.figure(figsize=(4,3))
plt.plot(nlayers, debru_10k_rh1_f1, '-x')
plt.plot(nlayers, debru_10k_rh0_f1, '-x')
plt.xticks(fontsize=7.5, rotation=0)
plt.yticks(fontsize=7.5, rotation=0)
plt.legend(['with residual', 'no residual'], fontsize=7.5, loc='best')
plt.xlabel('number of layers', fontsize=7.5)
plt.ylabel('F1', fontsize=7.5)
# plt.ylim([98.8, 100])
# plt.savefig('f1_vs_nlay_debru.pdf', bbox_inches='tight', dpi=200)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot(nlayers, kadem_10k_rh1_f1, '-x')
plt.plot(nlayers, kadem_10k_rh0_f1, '-x')
plt.xticks(fontsize=7.5, rotation=0)
plt.yticks(fontsize=7.5, rotation=0)
plt.legend(['with residual', 'no residual'], fontsize=7.5, loc='best')
plt.xlabel('number of layers', fontsize=7.5)
plt.ylabel('F1', fontsize=7.5)
# plt.ylim([98.8, 100])
# plt.savefig('f1_vs_nlay_kadem.pdf', bbox_inches='tight', dpi=200)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot(nlayers, chord_10k_rh1_f1, '-x')
plt.plot(nlayers, chord_10k_rh0_f1, '-x')
plt.xticks(fontsize=7.5, rotation=0)
plt.yticks(fontsize=7.5, rotation=0)
plt.legend(['with residual', 'no residual'], fontsize=7.5, loc='best')
plt.xlabel('number of layers', fontsize=7.5)
plt.ylabel('F1', fontsize=7.5)
# plt.ylim([98.8, 100])
# plt.savefig('f1_vs_nlay_chord.pdf', bbox_inches='tight', dpi=200)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot(nlayers, leet_10k_rh1_f1, '-x')
plt.plot(nlayers, leet_10k_rh0_f1, '-x')
plt.xticks(fontsize=7.5, rotation=0)
plt.yticks(fontsize=7.5, rotation=0)
plt.legend(['with residual', 'no residual'], fontsize=7.5, loc='best')
plt.xlabel('number of layers', fontsize=7.5)
plt.ylabel('F1', fontsize=7.5)
# plt.ylim([98.8, 100])
# plt.savefig('f1_vs_nlay_leet.pdf', bbox_inches='tight', dpi=200)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot(nlayers, c2_3k_rh1_f1, '-x')
plt.plot(nlayers, c2_3k_rh0_f1, '-x')
plt.xticks(fontsize=7.5, rotation=0)
plt.yticks(fontsize=7.5, rotation=0)
plt.legend(['with residual', 'no residual'], fontsize=7.5, loc='best')
plt.xlabel('number of layers', fontsize=7.5)
plt.ylabel('F1', fontsize=7.5)
# plt.ylim([98.8, 100])
# plt.savefig('f1_vs_nlay_C2.pdf', bbox_inches='tight', dpi=200)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot(nlayers, p2p_3k_rh1_f1, '-x')
plt.plot(nlayers, p2p_3k_rh0_f1, '-x')
plt.xticks(fontsize=7.5, rotation=0)
plt.yticks(fontsize=7.5, rotation=0)
plt.legend(['with residual', 'no residual'], fontsize=7.5, loc='best')
plt.xlabel('number of layers', fontsize=7.5)
plt.ylabel('F1', fontsize=7.5)
# plt.ylim([98.8, 100])
# plt.savefig('f1_vs_nlay_C2.pdf', bbox_inches='tight', dpi=200)
plt.show()

# %%
s = 1

# plt.figure(figsize=(4, 3))
# plt.figure(figsize=(3.5,2.6))
plt.figure(figsize=(3.2, 2.2))

plt.plot(nlayers[s:], debru_10k_rh1_f1[s:], '-o')
# plt.plot(nlayers[s:], debru_10k_rh0_f1[s:], 'y--x')
plt.plot(nlayers[s:], kadem_10k_rh1_f1[s:], '-<')
# plt.plot(nlayers[s:], kadem_10k_rh0_f1[s:], 'c--x')
plt.plot(nlayers[s:], chord_10k_rh1_f1[s:], 'k-v')
# plt.plot(nlayers[s:], chord_10k_rh0_f1[s:], '--x')
plt.plot(nlayers[s:], leet_10k_rh1_f1[s:], '->')
# plt.plot(nlayers[s:], leet_10k_rh0_f1[s:], '--x')
plt.xticks(fontsize=7.5, rotation=0)
plt.yticks(fontsize=7.5, rotation=0)

# plt.legend(['de Bruijn with residual', 'de Bruijn no residual', 'Chord with residual', 'Chord no residual'], fontsize=7.5, loc='best')
# plt.legend(['Kademlia with residual', 'Kademlia no residual', 'LEET-Chord with residual', 'LEET-Chord no residual'], fontsize=7.5, loc='best')
# plt.legend(['de Bruijn with residual', 'de Bruijn no residual', 'Kademlia with residual', 'Kademlia no residual', 
#             'Chord with residual', 'Chord no residual', 'LEET-Chord with residual', 'LEET-Chord no residual'], fontsize=7.5, loc='best')
plt.legend(['de Bruijn', 'Kademlia', 'Chord', 'LEET-Chord'], fontsize=7.5, loc='best')
            
plt.xlabel('number of layers', fontsize=7.5)
plt.xticks([2, 4, 6, 8, 10, 12])
plt.ylabel('F1 score', fontsize=7.5)
# plt.ylim([88.3, 100.5])

# plt.savefig('f1_vs_nlay_debru-chord.pdf', bbox_inches='tight', dpi=200)
# plt.savefig('f1_vs_nlay_kadem-leet.pdf', bbox_inches='tight', dpi=200)
# plt.savefig('f1_vs_nlay_all.pdf', bbox_inches='tight', dpi=200)
# plt.savefig('f1_vs_nlay_all_rh1.pdf', bbox_inches='tight', dpi=200)
# plt.savefig('f1_vs_nlay_all_rh0.pdf', bbox_inches='tight', dpi=200)
            
plt.show()

# %%
s = 1

# plt.figure(figsize=(4, 3))
plt.figure(figsize=(3.5,2.6))

plt.plot(nlayers[s:], c2_3k_rh1_f1[s:], '-o')
plt.plot(nlayers[s:], c2_3k_rh0_f1[s:], 'y--x')
plt.plot(nlayers[s:], p2p_3k_rh1_f1[s:], '-<')
plt.plot(nlayers[s:], p2p_3k_rh0_f1[s:], 'c--x')

plt.xticks(fontsize=7.5, rotation=0)
plt.yticks(fontsize=7.5, rotation=0)

plt.legend(['C2 with residual', 'C2 no residual','P2P with residual', 'P2P no residual'], fontsize=7.5, loc='best')
# plt.legend(['C2', 'P2P'], fontsize=7.5, loc='best')
            
plt.xlabel('number of layers', fontsize=7.5)
plt.ylabel('F1 score', fontsize=7.5)
# plt.ylim([88.3, 100.5])
            
# plt.savefig('f1_vs_nlay_c2-p2p.pdf', bbox_inches='tight', dpi=200)
# plt.savefig('f1_vs_nlay_c2-p2p_rh1.pdf', bbox_inches='tight', dpi=200)
# plt.savefig('f1_vs_nlay_c2-p2p_rh0.pdf', bbox_inches='tight', dpi=200)
            
plt.show()
